# %%
import numpy as np
import pandas as pd 
import os
import datetime

# load company stocks into dataframes

df_AAPL = pd.read_csv('/content/AAPL.csv')
df_AMZN = pd.read_csv('/content/AMZN.csv')
df_MSFT = pd.read_csv('/content/MSFT.csv')
df_NFLX = pd.read_csv('/content/NFLX.csv')
df_F =    pd.read_csv('/content/F.csv')
#df_HMC =  pd.read_csv('/content/HMC.csv')
#df_SMSN = pd.read_csv('/content/SMSN.IL.csv')
#df_TATA = pd.read_csv('/content/TATAMOTORS.NS.csv')
#df_TSLA = pd.read_csv('/content/TSLA.csv')
#df_WMT =  pd.read_csv('/content/WMT.csv')


df_AAPL.describe()

# Convert the 'Date' column to datetime format -1
 
df_AAPL['Date'] = df_AAPL['Date'].apply(lambda x: pd.to_datetime(x, format='%d-%m-%Y').strftime('%Y-%m-%d'))
df_AAPL['Date'] = pd.to_datetime(df_AAPL['Date'])

# show updated DataFrame
# print(df_AAPL.Date)

# Create a new dataframe with all the dates that should be present
min_date = df_AAPL['Date'].min()
max_date = df_AAPL['Date'].max()

date_range = pd.date_range(min_date, max_date, freq='D')

all_dates_df_AAPL = pd.DataFrame({'Date': date_range})

# Merge the original dataframe with the new dataframe, keeping all dates
merged_df_AAPL = pd.merge(all_dates_df_AAPL, df_AAPL, on='Date', how='left')


# Convert the 'Date' column to datetime format -2

df_MSFT['Date'] = df_MSFT['Date'].apply(lambda x: pd.to_datetime(x, format='%d-%m-%Y').strftime('%Y-%m-%d'))
df_MSFT['Date'] = pd.to_datetime(df_MSFT['Date'])

# show updated DataFrame
# print(df_MSFT.Date)

# Create a new dataframe with all the dates that should be present
min_date = df_MSFT['Date'].min()
max_date = df_MSFT['Date'].max()

date_range = pd.date_range(min_date, max_date, freq='D')

all_dates_df_MSFT = pd.DataFrame({'Date': date_range})

# Merge the original dataframe with the new dataframe, keeping all dates
merged_df_MSFT = pd.merge(all_dates_df_MSFT, df_MSFT, on='Date', how='left')



# Convert the 'Date' column to datetime format

df_AMZN['Date'] = df_AMZN['Date'].apply(lambda x: pd.to_datetime(x, format='%d-%m-%Y').strftime('%Y-%m-%d'))
df_AMZN['Date'] = pd.to_datetime(df_AMZN['Date'])

# show updated DataFrame
# print(df_AMZN.Date)

# Create a new dataframe with all the dates that should be present
min_date = df_AMZN['Date'].min()
max_date = df_AMZN['Date'].max()

date_range = pd.date_range(min_date, max_date, freq='D')

all_dates_df_AMZN = pd.DataFrame({'Date': date_range})

# Merge the original dataframe with the new dataframe, keeping all dates
merged_df_AMZN = pd.merge(all_dates_df_AMZN, df_AMZN, on='Date', how='left')



# Convert the 'Date' column to datetime format

df_F['Date'] = df_F['Date'].apply(lambda x: pd.to_datetime(x, format='%d-%m-%Y').strftime('%Y-%m-%d'))
df_F['Date'] = pd.to_datetime(df_F['Date'])

# show updated DataFrame
# print(df_F.Date)

# Create a new dataframe with all the dates that should be present
min_date = df_F['Date'].min()
max_date = df_F['Date'].max()

date_range = pd.date_range(min_date, max_date, freq='D')

all_dates_df_F = pd.DataFrame({'Date': date_range})

# Merge the original dataframe with the new dataframe, keeping all dates
merged_df_F = pd.merge(all_dates_df_F, df_F, on='Date', how='left')


# Convert the 'Date' column to datetime format

df_NFLX['Date'] = df_NFLX['Date'].apply(lambda x: pd.to_datetime(x, format='%d-%m-%Y').strftime('%Y-%m-%d'))
df_NFLX['Date'] = pd.to_datetime(df_NFLX['Date'])

# show updated DataFrame
#print(df_NFLX.Date)

# Create a new dataframe with all the dates that should be present
min_date = df_NFLX['Date'].min()
max_date = df_NFLX['Date'].max()

date_range = pd.date_range(min_date, max_date, freq='D')

all_dates_df_NFLX = pd.DataFrame({'Date': date_range})

# Merge the original dataframe with the new dataframe, keeping all dates
merged_df_NFLX = pd.merge(all_dates_df_NFLX, df_NFLX, on='Date', how='left')


print(merged_df_MSFT)
print(merged_df_AAPL)
print(merged_df_AMZN)
print(merged_df_F)
print(merged_df_NFLX)


merged_df_AAPL['Open'].interpolate(method ='linear',limit_direction='forward', inplace=True)
merged_df_AAPL['High'].interpolate(method ='linear',limit_direction='forward', inplace=True)
merged_df_AAPL['Low'].interpolate(method ='linear',limit_direction='forward', inplace=True)
merged_df_AAPL['Close'].interpolate(method ='linear',limit_direction='forward', inplace=True)
merged_df_AAPL['Adj Close'].interpolate(method ='linear',limit_direction='forward', inplace=True)
merged_df_AAPL['Volume'].interpolate(method ='linear',limit_direction='forward', inplace=True)


merged_df_AAPL['Open'].interpolate(method ='linear',limit_direction='forward', inplace=True)
merged_df_AAPL['High'].interpolate(method ='linear',limit_direction='forward', inplace=True)
merged_df_AAPL['Low'].interpolate(method ='linear',limit_direction='forward', inplace=True)
merged_df_AAPL['Close'].interpolate(method ='linear',limit_direction='forward', inplace=True)
merged_df_AAPL['Adj Close'].interpolate(method ='linear',limit_direction='forward', inplace=True)
merged_df_AAPL['Volume'].interpolate(method ='linear',limit_direction='forward', inplace=True)

merged_df_AMZN['Open'].interpolate(method ='linear',limit_direction='forward', inplace=True)
merged_df_AMZN['High'].interpolate(method ='linear',limit_direction='forward', inplace=True)
merged_df_AMZN['Low'].interpolate(method ='linear',limit_direction='forward', inplace=True)
merged_df_AMZN['Close'].interpolate(method ='linear',limit_direction='forward', inplace=True)
merged_df_AMZN['Adj Close'].interpolate(method ='linear',limit_direction='forward', inplace=True)
merged_df_AMZN['Volume'].interpolate(method ='linear',limit_direction='forward', inplace=True)

merged_df_MSFT['Open'].interpolate(method ='linear',limit_direction='forward', inplace=True)
merged_df_MSFT['High'].interpolate(method ='linear',limit_direction='forward', inplace=True)
merged_df_MSFT['Low'].interpolate(method ='linear',limit_direction='forward', inplace=True)
merged_df_MSFT['Close'].interpolate(method ='linear',limit_direction='forward', inplace=True)
merged_df_MSFT['Adj Close'].interpolate(method ='linear',limit_direction='forward', inplace=True)
merged_df_MSFT['Volume'].interpolate(method ='linear',limit_direction='forward', inplace=True)

merged_df_NFLX['Open'].interpolate(method ='linear',limit_direction='forward', inplace=True)
merged_df_NFLX['High'].interpolate(method ='linear',limit_direction='forward', inplace=True)
merged_df_NFLX['Low'].interpolate(method ='linear',limit_direction='forward', inplace=True)
merged_df_NFLX['Close'].interpolate(method ='linear',limit_direction='forward', inplace=True)
merged_df_NFLX['Adj Close'].interpolate(method ='linear',limit_direction='forward', inplace=True)
merged_df_NFLX['Volume'].interpolate(method ='linear',limit_direction='forward', inplace=True)

merged_df_F['Open'].interpolate(method ='linear',limit_direction='forward', inplace=True)
merged_df_F['High'].interpolate(method ='linear',limit_direction='forward', inplace=True)
merged_df_F['Low'].interpolate(method ='linear',limit_direction='forward', inplace=True)
merged_df_F['Close'].interpolate(method ='linear',limit_direction='forward', inplace=True)
merged_df_F['Adj Close'].interpolate(method ='linear',limit_direction='forward', inplace=True)
merged_df_F['Volume'].interpolate(method ='linear',limit_direction='forward', inplace=True)


print(merged_df_AAPL)
print(merged_df_AMZN)
print(merged_df_NFLX)
print(merged_df_MSFT)
print(merged_df_F)
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2017-12-01   83.599998   84.809998   83.220001   84.260002   79.150650
# 1    2017-12-02         NaN         NaN         NaN         NaN         NaN
# 2    2017-12-03         NaN         NaN         NaN         NaN         NaN
# 3    2017-12-04   84.419998   84.430000   80.699997   81.080002   76.163475
# 4    2017-12-05   81.339996   82.680000   80.980003   81.589996   76.642532
# ...         ...         ...         ...         ...         ...         ...
# 1954 2023-04-08         NaN         NaN         NaN         NaN         NaN
# 1955 2023-04-09         NaN         NaN         NaN         NaN         NaN
# 1956 2023-04-10  289.209991  289.600006  284.709991  289.390015  289.390015
# 1957 2023-04-11  285.750000  285.980011  281.640015  282.829987  282.829987
# 1958 2023-04-12  284.790009  287.010010  281.959991  283.489990  283.489990
#
#           Volume
# 0     29532100.0
# 1            NaN
# ...

# %%
for x in merged_df_AAPL : 
  merged_df_AAPL['Company'] = "AAPL"

print(merged_df_AAPL)

for x in merged_df_AMZN : 
  merged_df_AMZN['Company'] = "AMZN"

print(merged_df_AMZN)

for x in merged_df_MSFT : 
  merged_df_MSFT['Company'] = "MSFT"

print(merged_df_MSFT)

for x in merged_df_NFLX : 
  merged_df_NFLX['Company'] = "NFLX"

print(merged_df_NFLX)

for x in merged_df_F : 
  merged_df_F['Company'] = "F"

print(merged_df_F)
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2017-12-01   42.487499   42.917500   42.125000   42.762501   40.600857
# 1    2017-12-02   42.698332   42.996666   42.219167   42.658334   40.501958
# 2    2017-12-03   42.909166   43.075833   42.313334   42.554168   40.403060
# 3    2017-12-04   43.119999   43.154999   42.407501   42.450001   40.304161
# 4    2017-12-05   42.264999   42.880001   42.099998   42.410000   40.266174
# ...         ...         ...         ...         ...         ...         ...
# 1954 2023-04-08  161.924995  163.495003  161.040001  163.345001  163.345001
# 1955 2023-04-09  161.672497  162.762501  160.560001  162.687500  162.687500
# 1956 2023-04-10  161.419998  162.029999  160.080002  162.029999  162.029999
# 1957 2023-04-11  162.350006  162.360001  160.509995  160.800003  160.800003
# 1958 2023-04-12  161.220001  162.059998  159.779999  160.100006  160.100006
#
#             Volume Company
# 0     1.590372e+08    AAPL
# ...

# %%
# Split data into 80% and 20%
split_idx = int(0.8 * len(merged_df_AAPL))
train_df_AAPL = merged_df_AAPL[:split_idx]
test_df_AAPL = merged_df_AAPL[split_idx:]

print(train_df_AAPL)

# Split data into 80% and 20%
split_idx = int(0.8 * len(merged_df_AMZN))
train_df_AMZN = merged_df_AMZN[:split_idx]
test_df_AMZN = merged_df_AMZN[split_idx:]


# Split data into 80% and 20%
split_idx = int(0.8 * len(merged_df_NFLX))
train_df_NFLX = merged_df_NFLX[:split_idx]
test_df_NFLX = merged_df_NFLX[split_idx:]


# Split data into 80% and 20%
split_idx = int(0.8 * len(merged_df_MSFT))
train_df_MSFT = merged_df_MSFT[:split_idx]
test_df_MSFT = merged_df_MSFT[split_idx:]



# Split data into 80% and 20%
split_idx = int(0.8 * len(merged_df_F))
train_df_F = merged_df_F[:split_idx]
test_df_F = merged_df_F[split_idx:]
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 492  2019-04-07   49.107500   49.796667   49.050832   49.766668   48.166042
# 370  2018-12-06   42.939999   43.695000   42.605000   43.680000   42.094601
# 399  2019-01-04   36.132500   37.137501   35.950001   37.064999   35.719700
# 1784 2022-10-20  143.020004  145.889999  142.649994  143.389999  142.934296
# 581  2019-07-05   50.837502   51.270000   50.724998   51.057499   49.605663
# ...         ...         ...         ...         ...         ...         ...
# 1381 2021-09-12  152.086670  152.773331  148.733332  149.356669  148.052384
# 1157 2021-01-31  134.443334  135.833338  130.689998  133.413335  131.629807
# 1508 2022-01-17  171.467495  172.849995  169.830002  170.617504  169.374382
# 1028 2020-09-24  105.169998  110.250000  105.000000  108.220001  106.589378
# 414  2019-01-19   39.306875   39.398126   38.784999   38.985002   37.570012
#
#             Volume Company
# 492   9.372000e+07    AAPL
# ...

# %%
train_frames = [train_df_AAPL, train_df_AMZN,train_df_NFLX,train_df_MSFT,train_df_F]
test_frames = [test_df_AAPL,test_df_AMZN,test_df_NFLX,test_df_MSFT,test_df_F]
train_data = pd.concat(train_frames)
test_data = pd.concat(test_frames)

X_train = train_data.drop("Close",axis =1)
y_train = train_data['Close']

X_test = test_data.drop("Close",axis =1)
y_test = test_data['Close']

start_date = pd.to_datetime('2017-12-01')  # Replace with the start date of your choice
X_train['days_since_start'] = (pd.to_datetime(X_train['Date']) - start_date).dt.days
X_train = X_train.drop('Date',axis=1)

start_date = pd.to_datetime('2017-12-01')  # Replace with the start date of your choice
X_test['days_since_start'] = (pd.to_datetime(X_test['Date']) - start_date).dt.days
X_test = X_test.drop('Date',axis=1)


company_names = X_train['Company'].unique()

for company_name in company_names:
           X_train[f'{company_name}_flag'] = (X_train['Company'] == company_name).astype(int)


companies = X_test['Company'].unique()

for company_name in companies:
    X_test[f'{company_name}_flag'] = (X_test['Company'] == company_name).astype(int)


# Drop the original company name column
X_train = X_train.drop('Company', axis=1)
X_test = X_test.drop('Company',axis=1)




list = [X_train,X_test]
X = pd.concat(list)
list2 = [y_train,y_test]
y = pd.concat(list2)

# %%
from keras.models import Sequential
from keras.layers import Dense

# Define the model architecture
model = Sequential()
model.add(Dense(64, input_dim=X_train.shape[1], activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='linear'))



# Compile the model
model.compile(loss='mean_squared_error', optimizer='adam')

# Train the model
history = model.fit(X_train, y_train, epochs=100, batch_size=32, verbose=1, validation_split=0.2)
# Out:
# Epoch 1/100
# 196/196 [==============================] - 1s 3ms/step - loss: 104020410368.0000 - val_loss: 9655.0967
# Epoch 2/100
# 196/196 [==============================] - 0s 2ms/step - loss: 16466.0723 - val_loss: 16680.2207
# Epoch 3/100
# 196/196 [==============================] - 0s 2ms/step - loss: 15109.5557 - val_loss: 16790.5762
# Epoch 4/100
# 196/196 [==============================] - 1s 3ms/step - loss: 15714.9141 - val_loss: 23272.6875
# Epoch 5/100
# 196/196 [==============================] - 1s 3ms/step - loss: 16993.7266 - val_loss: 63122.6289
# Epoch 6/100
# 196/196 [==============================] - 1s 3ms/step - loss: 18145.6934 - val_loss: 11691.0312
# Epoch 7/100
# 196/196 [==============================] - 1s 3ms/step - loss: 19302.7461 - val_loss: 24377.6777
# Epoch 8/100
# 196/196 [==============================] - 1s 5ms/step - loss: 45973.4609 - val_loss: 36869.5195
# Epoch 9/100
# ...

# %%
y_predict = model.predict(X)
df = pd.DataFrame()

from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y, y_predict)


print(mae)
# Out:
# 307/307 [==============================] - 0s 1ms/step
# 54.463859977802265

# %%
for layer in model.layers:
    print(layer.get_weights())
# Out:
# [array([[ 5.64418472e-02,  1.53242812e-01, -3.60301793e-01,
#          5.12530841e-02,  2.28024930e-01, -8.11371207e-03,
#          2.12806731e-01,  4.23199646e-02, -2.03540698e-01,
#         -1.00011505e-01,  2.08651125e-01, -2.68887341e-01,
#          1.00505054e-02,  1.03069067e-01, -1.62326719e-03,
#         -3.61869484e-02,  1.05560988e-01, -1.37493610e-01,
#         -1.51977897e-01,  5.65181971e-02, -1.37844741e-01,
#         -4.27912623e-02,  3.78148630e-02,  2.37233371e-01,
#         -2.41457701e-01, -3.93602312e-01, -4.45346162e-02,
#          1.72785774e-01, -1.21913245e-02, -1.60379142e-01,
#         -2.43660659e-01, -2.26190060e-01, -1.02058640e-02,
#          2.49851272e-01,  4.31702323e-02,  1.15128808e-01,
#          4.04679403e-02, -7.34535158e-02, -3.14254314e-02,
#          4.49932218e-02,  2.83887595e-01,  1.61528647e-01,
#         -2.44995192e-01,  2.18709290e-01, -1.86595917e-02,
#         -4.66659933e-01, -1.50830345e-02,  2.23419666e-01,
# ...

# %%
pip install deap
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
pip install pygad
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.0/68.0 kB 2.3 MB/s eta 0:00:00
# ...

# %%
pip install --upgrade genetic_algorithm
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import random

# Define the fitness function
def fitness_function(weights, X, y):
    # Train a model with the given weights on the data X and y
    model = tf.keras.models.Sequential([
        tf.keras.layers.Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
        tf.keras.layers.Dense(32, activation ='relu'),
        tf.keras.layers.Dense(1, activation='linear')
    ])
    model.set_weights(weights)
    
    # Train the model
    model.compile(optimizer='adam', loss='mse',metrics = 'mae')
    model.fit(X_train, y_train, epochs=10, validation_data=(X_test, y_test))
    
    # Evaluate the model
    score = model.evaluate(X_test, y_test)
    
    # Return the negative of the evaluation metric to maximize it using genetic algorithm
    return -score

# Define the genetic algorithm
def genetic_algorithm(population_size, num_generations, mutation_rate, X, y):
    # Generate initial population
    population = []
    for i in range(population_size):
        # Generate a random set of weights
        weights = layer.get_weights()
        population.append(weights)

    # Evolve the population
    for generation in range(num_generations):
        # Evaluate fitness of each individual in the population
        fitness_scores = [fitness_function(weights, X, y) for weights in population]

        # Select parents for crossover
        parents = []
        for i in range(population_size):
            # Select two random individuals with probability proportional to their fitness
            parent1 = random.choices(population, weights=fitness_scores)[0]
            parent2 = random.choices(population, weights=fitness_scores)[0]
            parents.append((parent1, parent2))

        offspring = []
        for parent1, parent2 in parents:
            # Perform crossover operation on the parents to create a new child
            crossover_point = random.randint(0, len(parent1)-1)
            child = parent1[:crossover_point] + parent2[crossover_point:]
            offspring.append(child)

        # Mutate some individuals in the offspring
        for i in range(len(offspring)):
            if random.random() < mutation_rate:
                # Perform mutation operation on the child
                offspring[i] = ga.mutate(offspring[i],mutation_rate)

        # Replace the old population with the new offspring
        population = offspring

    # Return the best individual in the final population
    best_weights = max(population, key=lambda weights: fitness_function(weights, X, y))
    return best_weights
